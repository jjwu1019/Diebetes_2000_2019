# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#load csv
DiabetesAtlasData_Total_Percentage_df = pd.read_csv("DiabetesAtlasData_Total_Percentage.csv")
DiabetesAtlasData_Total_Number_df = pd.read_csv("DiabetesAtlasData_Total_Number.csv")
DiabetesAtlasData_Age_Percentage_df = pd.read_csv("DiabetesAtlasData_Age_Percentage.csv")
DiabetesAtlasData_Age_Number_df = pd.read_csv("DiabetesAtlasData_Age_Number.csv")
DiabetesAtlasData_Gender_Percentage_df = pd.read_csv("DiabetesAtlasData_Gender_Percentage.csv")
DiabetesAtlasData_Gender_Number_df = pd.read_csv("DiabetesAtlasData_Gender_Number.csv")
DiabetesAtlasData_Race_Percentage_df = pd.read_csv("DiabetesAtlasData_Race_Percentage.csv")
DiabetesAtlasData_Race_Number_df = pd.read_csv("DiabetesAtlasData_Race_Number.csv")
DiabetesAtlasData_Education_Percentage_df = pd.read_csv("DiabetesAtlasData_Education_Percentage.csv")
DiabetesAtlasData_Education_Number_df = pd.read_csv("DiabetesAtlasData_Education_Number.csv")

DiabetesAtlasData_Physical_Inactivity_2018_df = pd.read_csv("DiabetesAtlasData_Physical_Inactivity_2018.csv")
DiabetesAtlasData_Obesity_2018_df = pd.read_csv("DiabetesAtlasData_Obesity_2018.csv")
DiabetesAtlasData_Newly_Diagnosed_2018_df = pd.read_csv("DiabetesAtlasData_Newly_Diagnosed_2018.csv")
DiabetesAtlasData_Diagnosed_2018_df = pd.read_csv("DiabetesAtlasData_Diagnosed_2018.csv")

# %%
Physical_Inactivity_2018_df = DiabetesAtlasData_Physical_Inactivity_2018_df[['Year','County','State','Physical Inactivity Percentage']]
Physical_Inactivity_2018_df = Physical_Inactivity_2018_df.set_index('Year')
Obesity_2018_df = DiabetesAtlasData_Obesity_2018_df[['Year','Obesity Percentage']]
Obesity_2018_df = Obesity_2018_df.set_index('Year')
Newly_Diagnosed_2018_df = DiabetesAtlasData_Newly_Diagnosed_2018_df[['Year','Newly Diagnosed Diabetes Rate per 1000']]
Newly_Diagnosed_2018_df = Newly_Diagnosed_2018_df.set_index('Year')
Diagnosed_2018_df = DiabetesAtlasData_Diagnosed_2018_df[['Year','Diagnosed Diabetes Percentage']]
Diagnosed_2018_df = Diagnosed_2018_df.set_index('Year')
frames = [Physical_Inactivity_2018_df, Obesity_2018_df, Newly_Diagnosed_2018_df, Diagnosed_2018_df]
Social_Determinants_2018_df = pd.concat(frames, axis=1, join="inner")
#Social_Determinants_2018_df = Social_Determinants_2018_df[['County','State','Physical Inactivity Percentage','Obesity Percentage','Newly Diagnosed Diabetes Rate per 1000','Diagnosed Diabetes Percentage']]
Social_Determinants_2018_df
# Out:
#                  County    State  Physical Inactivity Percentage  \
# Year
# 2018     Autauga County  Alabama                            23.8
# 2018     Baldwin County  Alabama                            22.0
# 2018     Barbour County  Alabama                            23.2
# 2018        Bibb County  Alabama                            23.0
# 2018      Blount County  Alabama                            24.7
# ...                 ...      ...                             ...
# 2018  Sweetwater County  Wyoming                            23.2
# 2018       Teton County  Wyoming                            10.7
# 2018       Uinta County  Wyoming                            23.1
# 2018    Washakie County  Wyoming                            20.2
# 2018      Weston County  Wyoming                            21.8
#
#       Obesity Percentage  Newly Diagnosed Diabetes Rate per 1000  \
# Year
# 2018                29.6                                     9.1
# 2018                28.3                                     6.5
# 2018                29.3                                    11.5
# 2018                23.1                                    13.3
# 2018                27.8                                    12.9
# ...                  ...                                     ...
# 2018                31.0                                     7.0
# 2018                10.5                                     1.6
# 2018                33.2                                     7.6
# 2018                25.4                                    11.4
# 2018                32.0                                     7.9
#
#       Diagnosed Diabetes Percentage
# Year
# 2018                            9.5
# 2018                            8.4
# 2018                           13.5
# 2018                           10.2
# 2018                           10.5
# ...                             ...
# 2018                            7.8
# 2018                            3.8
# 2018                            8.4
# 2018                            7.4
# 2018                            7.6
#
# [3141 rows x 6 columns]

# %%
Total_Number_df = DiabetesAtlasData_Total_Number_df[['Year','Total - Number in 1000s']]
Total_Number_df = Total_Number_df.set_index('Year')
Age_Number_df = DiabetesAtlasData_Age_Number_df[['Year','18-44 - Number in 1000s','45-64 - Number in 1000s','65-74 - Number in 1000s','75+ - Number in 1000s']]
Age_Number_df = Age_Number_df.set_index('Year')
Gender_Number_df = DiabetesAtlasData_Gender_Number_df[['Year','Male - Number in 1000s','Female - Number in 1000s']]
Gender_Number_df = Gender_Number_df.set_index('Year')
Race_Number_df = DiabetesAtlasData_Race_Number_df[['Year', 'Hispanic - Number in 1000s','Non-Hispanic White - Number in 1000s','Non-Hispanic Black - Number in 1000s','Non-Hispanic Asian - Number in 1000s']]
Race_Number_df = Race_Number_df.set_index('Year')
Education_Number_df = DiabetesAtlasData_Education_Number_df[['Year','< High School - Number in 1000s','High School - Number in 1000s','> High School - Number in 1000s']]
Education_Number_df = Education_Number_df.set_index('Year')
frames = [Total_Number_df, Age_Number_df, Gender_Number_df, Race_Number_df, Education_Number_df]
Number_df = pd.concat(frames, axis=1, join="inner")
Number_df
# Out:
#       Total - Number in 1000s  18-44 - Number in 1000s  \
# Year
# 2000                    11863                     2059
# 2001                    13006                     2167
# 2002                    13391                     2080
# 2003                    14012                     2101
# 2004                    15126                     2173
# 2005                    16186                     2640
# 2006                    17110                     2924
# 2007                    17273                     2432
# 2008                    18651                     2553
# 2009                    20490                     3234
# 2010                    20974                     3022
# 2011                    20589                     2708
# 2012                    21319                     2673
# 2013                    22173                     2964
# 2014                    21872                     2710
# 2015                    23161                     2469
# 2016                    23104                     3142
# 2017                    23048                     3014
# 2018                    25158                     3777
# 2019                    23419                     2787
#
#       45-64 - Number in 1000s  65-74 - Number in 1000s  75+ - Number in 1000s  \
# Year
# 2000                     5040                     2810                   1954
# 2001                     5834                     2954                   2051
# 2002                     6030                     3029                   2252
# 2003                     6239                     3180                   2491
# 2004                     6963                     3393                   2598
# 2005                     7595                     3421                   2529
# 2006                     7752                     3469                   2965
# 2007                     8093                     3840                   2908
# 2008                     9223                     3940                   2935
# 2009                     9886                     4107                   3263
# 2010                     9676                     4563                   3713
# 2011                     9702                     4860                   3319
# 2012                    10273                     4863                   3509
# 2013                    10116                     5273                   3820
# 2014                     9945                     5654                   3563
# 2015                    10603                     6016                   4073
# 2016                    10082                     6272                   3608
# 2017                    10598                     5619                   3817
# 2018                    10320                     6580                   4481
# 2019                    10011                     6044                   4578
#
#       Male - Number in 1000s  Female - Number in 1000s  \
# Year
# 2000                    5907                      5956
# 2001                    6425                      6581
# 2002                    6826                      6565
# 2003                    6990                      7022
# 2004                    7541                      7585
# 2005                    7896                      8290
# 2006                    8204                      8906
# 2007                    8391                      8882
# 2008                    8934                      9717
# 2009                   10447                     10043
# 2010                   10804                     10170
# 2011                   10342                     10247
# 2012                   10357                     10961
# 2013                   11124                     11048
# 2014                   10907                     10965
# 2015                   11538                     11623
# 2016                   11499                     11605
# 2017                   12242                     10807
# 2018                   12760                     12397
# 2019                   11440                     11979
#
#       Hispanic - Number in 1000s  Non-Hispanic White - Number in 1000s  \
# Year
# 2000                        1344                                  8055
# 2001                        1502                                  8819
# 2002                        1542                                  9153
# 2003                        1556                                  9729
# 2004                        1879                                 10014
# 2005                        1898                                 11059
# 2006                        2147                                 11178
# 2007                        2316                                 10765
# 2008                        2524                                 12193
# 2009                        2879                                 13198
# 2010                        3178                                 13269
# 2011                        3051                                 13023
# 2012                        3166                                 13227
# 2013                        3409                                 13972
# 2014                        3459                                 13393
# 2015                        3616                                 14174
# 2016                        3746                                 14036
# 2017                        4087                                 13766
# 2018                        4303                                 14759
# 2019                        4005                                 13758
#
#       Non-Hispanic Black - Number in 1000s  \
# Year
# 2000                                  1947
# 2001                                  2058
# 2002                                  2029
# 2003                                  2089
# 2004                                  2353
# 2005                                  2484
# 2006                                  2736
# 2007                                  2822
# 2008                                  2687
# 2009                                  3191
# 2010                                  3144
# 2011                                  3147
# 2012                                  3382
# 2013                                  3246
# 2014                                  3575
# 2015                                  3586
# 2016                                  3659
# 2017                                  3233
# 2018                                  3603
# 2019                                  3565
#
#       Non-Hispanic Asian - Number in 1000s  < High School - Number in 1000s  \
# Year
# 2000                                   252                             3765
# 2001                                   267                             3920
# 2002                                   363                             3708
# 2003                                   336                             3678
# 2004                                   514                             3945
# 2005                                   427                             3991
# 2006                                   665                             4206
# 2007                                   798                             4466
# 2008                                   738                             4583
# 2009                                   758                             4847
# 2010                                   871                             4860
# 2011                                   877                             4880
# 2012                                   969                             4557
# 2013                                   953                             4587
# 2014                                   937                             4788
# 2015                                  1121                             4578
# 2016                                  1051                             4665
# 2017                                  1217                             4485
# 2018                                  1475                             4622
# 2019                                  1347                             5190
#
#       High School - Number in 1000s  > High School - Number in 1000s
# Year
# 2000                           3688                             4349
# 2001                           4329                             4614
# 2002                           4386                             5062
# 2003                           4064                             6027
# 2004                           4797                             6213
# 2005                           5093                             6942
# 2006                           5567                             7171
# 2007                           5562                             7043
# 2008                           6179                             7745
# 2009                           6579                             8924
# 2010                           6156                             9840
# 2011                           6109                             9453
# 2012                           6612                            10051
# 2013                           6586                            10902
# 2014                           6745                            10119
# 2015                           6858                            11605
# 2016                           6611                            11698
# 2017                           6317                            12105
# 2018                           7083                            13216
# 2019                           6788                            11214

# %%
Total_Percentage_df = DiabetesAtlasData_Total_Percentage_df[['Year','Total - Percentage']]
Total_Percentage_df = Total_Percentage_df.set_index('Year')
Age_Percentage_df = DiabetesAtlasData_Age_Percentage_df[['Year','18-44 - Percentage','45-64 - Percentage','65-74 - Percentage','75+ - Percentage']]
Age_Percentage_df = Age_Percentage_df.set_index('Year')
Gender_Percentage_df = DiabetesAtlasData_Gender_Percentage_df[['Year','Male - Percentage','Female - Percentage']]
Gender_Percentage_df = Gender_Percentage_df.set_index('Year')
Race_Percentage_df = DiabetesAtlasData_Race_Percentage_df[['Year', 'Hispanic - Percentage','Non-Hispanic White - Percentage','Non-Hispanic Black - Percentage','Non-Hispanic Asian - Percentage']]
Race_Percentage_df = Race_Percentage_df.set_index('Year')
Education_Percentage_df = DiabetesAtlasData_Education_Percentage_df[['Year','< High School - Percentage','High School - Percentage','> High School - Percentage']]
Education_Percentage_df = Education_Percentage_df.set_index('Year')
frames = [Total_Percentage_df, Age_Percentage_df, Gender_Percentage_df, Race_Percentage_df, Education_Percentage_df]
Percentage_df = pd.concat(frames, axis=1, join="inner")
Percentage_df
# Out:
#       Total - Percentage  18-44 - Percentage  45-64 - Percentage  \
# Year
# 2000                 6.0                 1.9                 8.3
# 2001                 6.4                 2.0                 9.3
# 2002                 6.5                 1.9                 9.3
# 2003                 6.6                 1.9                 9.1
# 2004                 7.0                 2.0                 9.9
# 2005                 7.3                 2.4                10.5
# 2006                 7.6                 2.7                10.5
# 2007                 7.5                 2.2                10.6
# 2008                 7.9                 2.3                11.9
# 2009                 8.6                 2.9                12.5
# 2010                 8.7                 2.7                12.1
# 2011                 8.4                 2.4                12.0
# 2012                 8.4                 2.4                12.5
# 2013                 8.7                 2.7                12.3
# 2014                 8.4                 2.4                12.0
# 2015                 8.7                 2.2                12.8
# 2016                 8.5                 2.8                12.1
# 2017                 8.5                 2.7                12.7
# 2018                 9.1                 3.3                12.4
# 2019                 8.3                 2.4                12.2
#
#       65-74 - Percentage  75+ - Percentage  Male - Percentage  \
# Year
# 2000                15.8              13.2                6.4
# 2001                16.7              13.6                6.9
# 2002                17.0              14.8                7.2
# 2003                17.6              15.5                7.1
# 2004                18.5              16.0                7.5
# 2005                18.6              15.3                7.7
# 2006                18.2              17.9                7.8
# 2007                20.0              17.3                7.9
# 2008                19.8              16.9                8.1
# 2009                19.9              18.9                9.4
# 2010                21.4              21.3                9.6
# 2011                22.2              18.7                9.0
# 2012                20.5              19.4                8.7
# 2013                21.0              20.9                9.2
# 2014                21.5              19.2                8.9
# 2015                22.1              21.2                9.2
# 2016                22.0              18.6                9.0
# 2017                19.1              19.0                9.5
# 2018                21.4              21.8                9.8
# 2019                19.5              20.7                8.7
#
#       Female - Percentage  Hispanic - Percentage  \
# Year
# 2000                  5.6                    8.8
# 2001                  6.1                    9.2
# 2002                  6.0                    9.2
# 2003                  6.1                    8.5
# 2004                  6.5                   10.1
# 2005                  7.0                    9.6
# 2006                  7.4                   10.3
# 2007                  7.3                   10.9
# 2008                  7.8                   10.8
# 2009                  7.9                   12.2
# 2010                  7.9                   13.0
# 2011                  7.9                   11.9
# 2012                  8.2                   12.0
# 2013                  8.2                   12.3
# 2014                  7.9                   11.8
# 2015                  8.3                   12.0
# 2016                  8.2                   11.7
# 2017                  7.6                   12.5
# 2018                  8.6                   12.4
# 2019                  8.1                   11.0
#
#       Non-Hispanic White - Percentage  Non-Hispanic Black - Percentage  \
# Year
# 2000                              5.2                             10.1
# 2001                              5.6                             10.3
# 2002                              5.8                              9.9
# 2003                              5.9                             10.0
# 2004                              6.0                             11.1
# 2005                              6.6                             11.3
# 2006                              6.7                             11.8
# 2007                              6.3                             12.3
# 2008                              7.0                             11.1
# 2009                              7.6                             13.0
# 2010                              7.5                             12.6
# 2011                              7.2                             12.5
# 2012                              7.2                             12.8
# 2013                              7.6                             12.3
# 2014                              7.1                             13.0
# 2015                              7.4                             12.8
# 2016                              7.4                             12.7
# 2017                              7.3                             11.0
# 2018                              7.8                             12.4
# 2019                              7.0                             11.9
#
#       Non-Hispanic Asian - Percentage  < High School - Percentage  \
# Year
# 2000                              4.5                         9.2
# 2001                              5.0                         9.8
# 2002                              6.2                         9.8
# 2003                              6.3                         9.2
# 2004                              7.5                         9.8
# 2005                              6.3                        10.3
# 2006                              8.2                         9.9
# 2007                              8.7                        11.5
# 2008                              7.9                        11.9
# 2009                              8.1                        12.9
# 2010                              9.0                        12.5
# 2011                              8.5                        12.9
# 2012                              8.7                        12.3
# 2013                              8.0                        12.2
# 2014                              7.5                        12.9
# 2015                              8.5                        12.7
# 2016                              7.4                        12.9
# 2017                              8.6                        13.2
# 2018                             10.0                        13.4
# 2019                              9.1                        13.5
#
#       High School - Percentage  > High School - Percentage
# Year
# 2000                       5.9                         4.8
# 2001                       7.0                         4.9
# 2002                       6.9                         5.3
# 2003                       6.1                         5.9
# 2004                       7.1                         5.9
# 2005                       7.4                         6.3
# 2006                       8.2                         6.5
# 2007                       7.9                         6.1
# 2008                       9.0                         6.2
# 2009                       9.4                         7.1
# 2010                       9.0                         7.5
# 2011                       8.9                         6.9
# 2012                       9.5                         7.0
# 2013                       9.4                         7.5
# 2014                       9.5                         6.7
# 2015                       9.8                         7.4
# 2016                       9.4                         7.2
# 2017                       9.2                         7.2
# 2018                      10.2                         7.8
# 2019                       8.7                         6.9

# %%
plt.figure(figsize=(18, 18))
sns.heatmap(Social_Determinants_2018_df.corr(), cmap='YlGnBu', annot=True);
plt.savefig('Social_Determinants_2018_corr.png', dpi = 1800)

# %%
plt.figure(figsize=(18, 18))
sns.heatmap(Number_df.corr(), cmap='YlGnBu', annot=True);
plt.savefig('Number_corr.png', dpi = 1800)

# %%
plt.figure(figsize=(18, 18))
sns.heatmap(Percentage_df.corr(), cmap='YlGnBu', annot=True);
plt.savefig('Percentage_corr.png', dpi = 1800)

# %%
year = list(Total_Percentage_df.index.values)
Total_Percentage_df.plot(use_index=True, xticks = year)
plt.xticks(rotation=90)
plt.grid()
plt.savefig('Total_Percentage.png', dpi = 1200)

# %%
year = list(Total_Number_df.index.values)
Total_Number_df.plot(use_index=True, xticks = year)
plt.xticks(rotation=90)
plt.grid()
plt.savefig('Total_Number.png', dpi = 1200)

# %%
year = list(Age_Percentage_df.index.values)
Age_Percentage_df.plot(use_index=True, xticks = year)
plt.xticks(rotation=90)
plt.grid()
plt.savefig('Age_Percentage.png', dpi = 1200)

# %%
year = list(Age_Number_df.index.values)
Age_Number_df.plot(use_index=True, xticks = year)
plt.xticks(rotation=90)
plt.grid()
plt.savefig('Age_Number.png', dpi = 1200)

# %%
year = list(Gender_Percentage_df.index.values)
Gender_Percentage_df.plot(use_index=True, xticks = year)
plt.xticks(rotation=90)
plt.grid()
plt.savefig('Gender_Percentage.png', dpi = 1200)

# %%
year = list(Gender_Number_df.index.values)
Gender_Number_df.plot(use_index=True, xticks = year)
plt.xticks(rotation=90)
plt.grid()
plt.savefig('Gender_Number.png', dpi = 1200)

# %%
year = list(Race_Percentage_df.index.values)
Race_Percentage_df.plot(use_index=True, xticks = year)
plt.xticks(rotation=90)
plt.grid()
plt.savefig('Race_Percentage.png', dpi = 1200)

# %%
year = list(Race_Number_df.index.values)
Race_Number_df.plot(use_index=True, xticks = year)
plt.xticks(rotation=90)
plt.grid()
plt.savefig('Race_Number.png', dpi = 1200)

# %%
year = list(Education_Percentage_df.index.values)
Education_Percentage_df.plot(use_index=True, xticks = year)
plt.xticks(rotation=90)
plt.grid()
plt.savefig('Education_Percentage.png', dpi = 1200)

# %%
year = list(Education_Number_df.index.values)
Education_Number_df.plot(use_index=True, xticks = year)
plt.xticks(rotation=90)
plt.grid()
plt.savefig('Education_Number.png', dpi = 1200)

# %%
Number_2019_df = Number_df.loc[2019]
Number_2019_df
# Out:
# Total - Number in 1000s                 23419
# 18-44 - Number in 1000s                  2787
# 45-64 - Number in 1000s                 10011
# 65-74 - Number in 1000s                  6044
# 75+ - Number in 1000s                    4578
# Male - Number in 1000s                  11440
# Female - Number in 1000s                11979
# Hispanic - Number in 1000s               4005
# Non-Hispanic White - Number in 1000s    13758
# Non-Hispanic Black - Number in 1000s     3565
# Non-Hispanic Asian - Number in 1000s     1347
# < High School - Number in 1000s          5190
# High School - Number in 1000s            6788
# > High School - Number in 1000s         11214
# Name: 2019, dtype: int64

# %%
Number_2019_df.plot.bar()
plt.savefig('Number_2019.png', dpi = 1200)

# %%
Percentage_2019_df = Percentage_df.loc[2019]
Percentage_2019_df
# Out:
# Total - Percentage                  8.3
# 18-44 - Percentage                  2.4
# 45-64 - Percentage                 12.2
# 65-74 - Percentage                 19.5
# 75+ - Percentage                   20.7
# Male - Percentage                   8.7
# Female - Percentage                 8.1
# Hispanic - Percentage              11.0
# Non-Hispanic White - Percentage     7.0
# Non-Hispanic Black - Percentage    11.9
# Non-Hispanic Asian - Percentage     9.1
# < High School - Percentage         13.5
# High School - Percentage            8.7
# > High School - Percentage          6.9
# Name: 2019, dtype: float64

# %%
Percentage_2019_df.plot.bar()
plt.savefig('Percentage_2019.png', dpi = 1200)
